# %%
print("hello","world")
print('iot class')
print(1025)

print('''iot class''')
# Out:
# hello world
# iot class
# 1025
# iot class

# %%
x=3
name="mm"
rollno="23L-6006"
y=3.5
print("the no. is: ",x)
print("name is: ",name)
print("float number: ",y)
print(type(x))

print(type(rollno))

print(type(y))

type(y)
# Out:
# the no. is:  3
# name is:  mm
# float number:  3.5
# <class 'int'>
# <class 'str'>
# <class 'float'>
# float

# %%
x1='abc'
x2=False
x3=True
x4=3.5
x5=7
x6=complex(4)
x7=complex(4,6)

print(type(x2))

print(x7)
# Out:
# <class 'bool'>
# (4+6j)

# %%
x2=3
x4=False
x6=complex(4)
x7=complex(4,6)

print(type(x2))

print(x7)
print(x6)
# Out:
# <class 'int'>
# (4+6j)
# (4+0j)

# %%
print('hehejjj')
# Out:
# hehejjj
