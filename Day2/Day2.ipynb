# %% [markdown]
#   TYPE CASTING
#    /          \
# IMPLICIT   EXPLICIT
# |            |
# COMPILER   USER
#
#
# Conversion
#
# a=5
# b=2.5
# sum=a+b  -> sum=int(sum)
# print(sum)
# n= int(input("enter a number"))  // int means type casting, it takes value in int

# %% [markdown]
# Variables & Datatypes   ( int,float,bool,string,complex)
#
# x=2
# print(type(x))

# %% [markdown]
# Arthematic
#
# + - *  %
# -> simple division
# -> // interger divison
# ** ->power

# %% [markdown]
# Relational
#
# == != > <  <= >=
#
# a=5
# b=2
# print(a>=b)

# %% [markdown]
# Logical
#
# and, or, not
#
# print(not true)
#
# print((a>b) &&(a==b))
#
#
# +=
# -=
# /=
# %=
#
# a**=2  --> a = (**)^2

# %%
name=input("enter your name:")
print("Your name is: ", name)
# Out:
# Your name is:  mudassir

# %%
x1= 2
x2= 5.4
x3='''ali'''
x4=True
x5=False
x6=4+2j
print(type(x1))
print(type(x2))
print(type(x3))
print(type(x4))
print(type(x5))
print(type(x6))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>
# <class 'complex'>

# %%
a,b=2,4
print(a,b)
# Out:
# 2 4

# %%
a=4
b=2
print(a/b)
print(a//b)
print(a**2)
print(complex(4))
print(complex(4,2))
print(not True)
print((a>b) and (a==b))
# Out:
# 2.0
# 2
# 16
# (4+0j)
# (4+2j)
# False
# False
